# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
o_df=pd.read_excel("Online_Retail_Subset.xlsx",'Sheet1')

# %%
o_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
o_df.describe().T
# Out:
#               count          mean          std      min       25%       50%  \
# Quantity    14999.0      7.464098    85.930115  -9360.0      1.00      2.00
# UnitPrice   14999.0      4.103366    20.106207      0.0      1.25      2.51
# CustomerID  10728.0  15590.606264  1764.101280  12347.0  14213.00  15658.00
#
#                  75%       max
# Quantity        7.00   2880.00
# UnitPrice       4.21    950.99
# CustomerID  17218.00  18239.00

# %%
o_df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
o_df.shape
# Out:
# (14999, 8)

# %%
o_df.isna().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description      60
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     4271
# Country           0
# dtype: int64

# %%
o_df["Description"].fillna(o_df['Description'].mode()[0],inplace=True)

# %%
o_df.isna().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description       0
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     4271
# Country           0
# dtype: int64

# %%
o_df=o_df.dropna()

# %%
o_df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
o_df['Quantity'].where(o_df['Quantity']<0).count()
# Out:
# 151

# %%
o_df["Quantity"]=o_df["Quantity"].abs()
o_df.describe()
# Out:
#            Quantity     UnitPrice    CustomerID
# count  10728.000000  10728.000000  10728.000000
# mean      11.440343      3.123054  15590.606264
# std      101.147945      5.330112   1764.101280
# min        1.000000      0.000000  12347.000000
# 25%        1.000000      1.250000  14213.000000
# 50%        4.000000      2.100000  15658.000000
# 75%       12.000000      3.750000  17218.000000
# max     9360.000000    295.000000  18239.000000

# %%
o_df.replace(b,a,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fbb962f773ca> in <module>
# ----> 1 o_df.replace(b,a,inplace=True)
#
# NameError: name 'b' is not defined

# %%
o_df['Quantity'].where(o_df['Quantity']<0).count()
# Out:
# 0

# %%
o_df['Quantity'].unique()
# Out:
# array([   6,    8,    2,   32,    3,    4,   24,   12,   48,   18,   20,
#          36,   80,   64,   10,  120,   96,   23,    5,    1,   50,   40,
#         100,  192,  432,  144,  288,   16,    9,  128,   25,   30,   28,
#           7,   72,  200,  600,  480,   14,   11,   70,  252,   60,  216,
#         384,   27,  108,   52, 9360,   75,  270,   42,  240,   90,  320,
#          17, 1824,  204,   69,  160, 2880, 1400,   19,   39,   56,   13,
#        1440,   15,  720,  156,  324,   41,  402,  378,  150,  300,   22,
#          34], dtype=int64)

# %%
o_df.describe().T
# Out:
#               count          mean          std      min       25%      50%  \
# Quantity    10728.0     11.440343   101.147945      1.0      1.00      4.0
# UnitPrice   10728.0      3.123054     5.330112      0.0      1.25      2.1
# CustomerID  10728.0  15590.606264  1764.101280  12347.0  14213.00  15658.0
#
#                  75%      max
# Quantity       12.00   9360.0
# UnitPrice       3.75    295.0
# CustomerID  17218.00  18239.0

# %%
import re
o_df['InvoiceNo'].replace('C','',regex=True,inplace=True)
o_df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5        536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6        536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7        536366     22633               HAND WARMER UNION JACK         6
# 8        536366     22632            HAND WARMER RED POLKA DOT         6
# 9        536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10       536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11       536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
o_df['InvoiceNo'].where(o_df['InvoiceNo']=='C%').count()
# Out:
# 0

# %%
import re
o_df['StockCode'].replace('[A-Z]','',regex=True,inplace=True)
o_df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# 5        536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6        536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7        536366     22633               HAND WARMER UNION JACK         6
# 8        536366     22632            HAND WARMER RED POLKA DOT         6
# 9        536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10       536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11       536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %%
label_encoder=LabelEncoder()
o_df["Description"]=label_encoder.fit_transform(o_df['Description'])
o_df["Country"]=label_encoder.fit_transform(o_df["Country"])

# %%
b=o_df.drop(columns='InvoiceDate')

# %%
scaler=MinMaxScaler()
scaled_val=scaler.fit_transform(b)
scaled_val=pd.DataFrame(scaled_val,columns=o_df.columns)
o_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-ae796f10c20d> in <module>
#       1 scaler=MinMaxScaler()
# ----> 2 scaled_val=scaler.fit_transform(b)
#       3 scaled_val=pd.DataFrame(scaled_val,columns=o_df.columns)
#       4 o_df.head()
#
# C:\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# C:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# --> 323         return self.partial_fit(X, y)
#     324
# ...

# %%
o_df['Total']=o_df['UnitPrice']*o_df['Quantity']

# %%
o_df.head()
# Out:
#   InvoiceNo StockCode  Description  Quantity         InvoiceDate  UnitPrice  \
# 0    536365     85123         1793         6 2010-12-01 08:26:00       2.55
# 1    536365     71053         1796         6 2010-12-01 08:26:00       3.39
# 2    536365     84406          479         8 2010-12-01 08:26:00       2.75
# 3    536365     84029          907         6 2010-12-01 08:26:00       3.39
# 4    536365     84029         1351         6 2010-12-01 08:26:00       3.39
#
#    CustomerID  Country  Total
# 0     17850.0       15  15.30
# 1     17850.0       15  20.34
# 2     17850.0       15  22.00
# 3     17850.0       15  20.34
# 4     17850.0       15  20.34
